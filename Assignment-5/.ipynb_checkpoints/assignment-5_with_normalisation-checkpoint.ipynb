# %% [markdown]
# ##### importing libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
from mlxtend.data import loadlocal_mnist
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### loading data, reshaping, onehot encoding of labels

# %%
def load_data():
    xtrain,ytrain = loadlocal_mnist(images_path = "train-images-idx3-ubyte",labels_path = 'train-labels-idx1-ubyte')
    xtest,ytest = loadlocal_mnist(images_path = 't10k-images-idx3-ubyte',labels_path = 't10k-labels-idx1-ubyte')
    xtrain=xtrain.reshape(xtrain.shape[0],28,28,1)
    xtest=xtest.reshape(xtest.shape[0],28,28,1)
    # compute the number of labels
    num_labels = np.amax(ytrain) + 1
    #print(num_labels)
    # convert to one-hot vector
    ytrain = np.eye(num_labels)[ytrain.astype('int32')]
    ytest = np.eye(num_labels)[ytest.astype('int32')]
    #print(ytrain.shape,ytest.shape)
    return xtrain,ytrain,xtest,ytest

# %% [markdown]
# #### function for displaying images

# %%
def display(x,y):
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    xp=x.reshape(x.shape[0],28,28)
    a=[np.where(r==1)[0][0] for r in y]
    plt.figure(figsize=(10,10))
    for i in range(100):
        plt.subplot(10,10,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(xp[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[a[i]])
    plt.show()

# %% [markdown]
# ## data augmentation of 10k images and concatenation

# %%
xtrain,ytrain,xtest,ytest=load_data()
def transform(x,y): 
    transform_size=10000
    datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range = 0.05, 
        width_shift_range=0.05,
        height_shift_range=0.05,
        horizontal_flip=True,
        vertical_flip=True, 
        data_format="channels_last",
        zca_whitening=True)
    # fit data for zca whitening
    datagen.fit(x)
    #image_generator.fit(y_train, augment=True)
    # get transformed images
    randidx = np.random.randint(x.shape[0], size=transform_size)
    xaug = x[randidx].copy()
    yaug = y[randidx].copy()
    xaug = datagen.flow(xaug, np.zeros(transform_size),
                                batch_size=transform_size, shuffle=False).next()[0]
    # append augmented data to trainset
    display(xaug,yaug)
    plt.show()
    x = np.concatenate((x, xaug))
    y = np.concatenate((y, yaug))
    return x,y

# %%
xtrain,ytrain=transform(xtrain,ytrain)

# %% [markdown]
# #### randominising the added images

# %%
def randomize(x, y):
    """ Randomizes the order of data samples and their corresponding labels"""
    permutation = np.random.permutation(y.shape[0])
    shuffled_x = x[permutation, :, :, :]
    shuffled_y = y[permutation,:]
    return shuffled_x, shuffled_y

xtrain,ytrain=randomize(xtrain,ytrain)

# %% [markdown]
# #### scaling and spliting the data

# %%
# we train our network using float data
xtrain = xtrain.astype('float32') / 255
xtest = xtest.astype('float32') / 255

xtrain,xvalid,ytrain,yvalid=train_test_split(xtrain,ytrain,test_size=0.02,random_state=42)

# %% [markdown]
# #### def funcs for weights bias conv_layer maxpool fc

# %%
# weight and bais wrappers
def weight_variable(shape):
    initer = tf.truncated_normal_initializer(stddev=0.01)
    return tf.get_variable('W',
                           dtype=tf.float32,
                           shape=shape,
                           initializer=initer)
def bias_variable(shape):
    initial = tf.constant(0., shape=shape, dtype=tf.float32)
    return tf.get_variable('b',
                           dtype=tf.float32,
                           initializer=initial)
def conv_layer(x, filter_size, num_filters, stride, name,batch_norm=False,drop_out=False):
    with tf.variable_scope(name):
        num_in_channel = x.get_shape().as_list()[-1]
        shape = [filter_size, filter_size, num_in_channel, num_filters]
        W = weight_variable(shape=shape)
        tf.summary.histogram('weight', W)
        b = bias_variable(shape=[num_filters])
        tf.summary.histogram('bias', b)
        layer = tf.nn.conv2d(x, W,
                             strides=[1, stride, stride, 1],
                             padding="SAME")
        
        layer += b
        layer = tf.nn.relu(layer)
        if(drop_out):
            layer = tf.layers.dropout(layer,rate=0.5)
        if(batch_norm):
            layer = tf.layers.batch_normalization(layer)
        return layer
    
def max_pool(x, ksize, stride, name):
    return tf.nn.max_pool(x,
                          ksize=[1, ksize, ksize, 1],
                          strides=[1, stride, stride, 1],
                          padding="SAME",
                          name=name)
def flatten_layer(layer):
    with tf.variable_scope('Flatten_layer'):
        layer_shape = layer.get_shape()
        num_features = layer_shape[1:4].num_elements()
        layer_flat = tf.reshape(layer, [-1, num_features])
    return layer_flat

def fc_layer(x, num_units, name, use_relu=True):
    with tf.variable_scope(name):
        in_dim = x.get_shape()[1]
        W = weight_variable(shape=[in_dim, num_units])
        tf.summary.histogram('weight', W)
        b = bias_variable(shape=[num_units])
        tf.summary.histogram('bias', b)
        layer = tf.matmul(x, W)
        layer += b
        if use_relu:
            layer = tf.nn.relu(layer)
        return layer

# %% [markdown]
# #### defining variables

# %%
img_h = img_w = 28  # MNIST images are 28x28
img_size_flat = img_h * img_w  # 28x28=784, the total number of pixels
n_classes = 10  # Number of classes, one class per digit
n_channels = 1
# 1st Convolutional Layer
filter_size1 = 3  # Convolution filters are 5 x 5 pixels.
num_filters1 = 16  # There are 16 of these filters.
stride1 = 1  # The stride of the sliding window

# 2nd Convolutional Layer
filter_size2 = 3  # Convolution filters are 5 x 5 pixels.
num_filters2 = 32  # There are 32 of these filters.
stride2 = 1  # The stride of the sliding window

# Fully-connected layer.
h1 = 128  # Number of neurons in fully-connected layer.

# %% [markdown]
# #### defining input for nn

# %%
with tf.name_scope('Input'):
    x = tf.placeholder(tf.float32, shape=[None, img_h, img_w, n_channels], name='X')
    y = tf.placeholder(tf.float32, shape=[None, n_classes], name='Y')

# %% [markdown]
# ### defining layers

# %%
#pool1 = max_pool(x, ksize=2, stride=2, name='pool1')
# print(pool1.shape)
# print(x.shape)
conv1 = conv_layer(x, filter_size1, num_filters1, stride1, name='conv1',batch_norm=True,drop_out=True)
#pool2 = max_pool(conv1, ksize=2, stride=2, name='pool2')
conv2 = conv_layer(conv1, filter_size2, num_filters2, stride2, name='conv2',batch_norm=True,drop_out=False)
pool3 = max_pool(conv2, ksize=2, stride=2, name='pool3')
layer_flat = flatten_layer(pool3)
fc1 = fc_layer(layer_flat, h1, 'FC1', use_relu=True)
output_logits = fc_layer(fc1, n_classes, 'OUT', use_relu=False)
# Out:
# WARNING:tensorflow:From /home/deepak/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-8-2aca886c2d3c>:28: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From <ipython-input-8-2aca886c2d3c>:30: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.batch_normalization instead.

# %% [markdown]
# ### storing path and learning rate

# %%
logs_path = "./logs"  # path to the folder that we want to save the logs for Tensorboard
lr = 0.01  # The optimization initial learning rate

# %%
with tf.variable_scope('Train'):
    with tf.variable_scope('Loss'):
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output_logits), name='loss')
    tf.summary.scalar('loss', loss)
    with tf.variable_scope('Optimizer'):
        optimizer = tf.train.AdamOptimizer(learning_rate=lr, name='Adam-op').minimize(loss)
    with tf.variable_scope('Accuracy'):
        correct_prediction = tf.equal(tf.argmax(output_logits, 1), tf.argmax(y, 1), name='correct_pred')
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
    tf.summary.scalar('accuracy', accuracy)
    with tf.variable_scope('Prediction'):
        cls_prediction = tf.argmax(output_logits, axis=1, name='predictions')
# Out:
# WARNING:tensorflow:From <ipython-input-13-a27d961557ec>:3: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
def get_next_batch(x, y, start, end):
    x_batch = x[start:end]
    y_batch = y[start:end]
    return x_batch, y_batch

# %%
# Initialize the variables
init = tf.global_variables_initializer()
# Merge all summaries
merged = tf.summary.merge_all()

# %%
epochs = 50  # Total number of training epochs
batch_size = 100  # Training batch size
display_freq = 100  # Frequency of displaying the training results
loss_n=0.25

# %%
sess = tf.InteractiveSession()
sess.run(init)
global_step = 0
summary_writer = tf.summary.FileWriter(logs_path, sess.graph)
acc_valid_p=0
stop=5
counter=0
#Create a saver object which will save all the variables
saver = tf.train.Saver()
# Number of training iterations in each epoch
num_tr_iter = int(len(ytrain) / batch_size)
for epoch in range(epochs):
    print('Training epoch: {}'.format(epoch + 1))
    
    #x_train, y_train = randomize(xtrain, ytrain)
    for iteration in range(num_tr_iter):
        global_step += 1
        start = iteration * batch_size
        end = (iteration + 1) * batch_size
        x_batch, y_batch = get_next_batch(xtrain, ytrain, start, end)

        # Run optimization op (backprop)
        feed_dict_batch = {x: x_batch, y: y_batch}
        sess.run(optimizer, feed_dict=feed_dict_batch)

        if iteration % display_freq == 0:
            # Calculate and display the batch loss and accuracy
            loss_batch, acc_batch, summary_tr = sess.run([loss, accuracy, merged],
                                                         feed_dict=feed_dict_batch)
            summary_writer.add_summary(summary_tr, global_step)
            
            print("iter {0:3d}:\t Loss={1:.2f},\tTraining Accuracy={2:.01%}".
                  format(iteration, loss_batch, acc_batch))

            
        if loss_batch<loss_n:
            lr=lr*0.1
            loss_n-=0.02
            print("lr is changed", lr)
            
            
     # Run validation after every epoch
    feed_dict_valid = {x: xvalid, y: yvalid}
    loss_valid, acc_valid = sess.run([loss, accuracy], feed_dict=feed_dict_valid)
    print('---------------------------------------------------------')
    print("Epoch: {0}, validation loss: {1:.2f}, validation accuracy: {2:.01%}".
          format(epoch + 1, loss_valid, acc_valid))
    print('---------------------------------------------------------')

#     if loss_p>loss_valid:
#         loss_p=loss_valid
#         counter_loss=0
#     elif:
#         if loss_p-loss_valid<0.5:
#             lr=0.001
#             print("lr is changed to 0.001")
#             counter_loss+=1
#         if loss_p-loss_valid<0.2:
#             lr=0.0001
#             print("lr is changed to 0.0001")
    
        
    if epoch>4:
        if acc_valid_p<acc_valid:
            counter=0
            acc_valid_p=acc_valid
            saved_path = saver.save(sess, './saved_variable')
            print('model saved in {}'.format(saved_path))
        elif counter<stop:
            counter+=1
        else:
            print("Early stopping")
            break
    else:
        pass
# Out:
# Training epoch: 1
# iter   0:	 Loss=2.28,	Training Accuracy=17.0%
# iter 100:	 Loss=0.80,	Training Accuracy=72.0%
# iter 200:	 Loss=0.66,	Training Accuracy=75.0%
# iter 300:	 Loss=0.63,	Training Accuracy=77.0%
# iter 400:	 Loss=0.44,	Training Accuracy=87.0%
# iter 500:	 Loss=0.47,	Training Accuracy=82.0%
# iter 600:	 Loss=0.53,	Training Accuracy=78.0%
# ---------------------------------------------------------
# Epoch: 1, validation loss: 0.59, validation accuracy: 77.7%
# ---------------------------------------------------------
# Training epoch: 2
# iter   0:	 Loss=0.51,	Training Accuracy=84.0%
# iter 100:	 Loss=0.53,	Training Accuracy=79.0%
# iter 200:	 Loss=0.57,	Training Accuracy=77.0%
# iter 300:	 Loss=0.48,	Training Accuracy=84.0%
# iter 400:	 Loss=0.49,	Training Accuracy=81.0%
# iter 500:	 Loss=0.44,	Training Accuracy=82.0%
# iter 600:	 Loss=0.48,	Training Accuracy=83.0%
# ---------------------------------------------------------
# Epoch: 2, validation loss: 0.50, validation accuracy: 80.5%
# ---------------------------------------------------------
# Training epoch: 3
# iter   0:	 Loss=0.36,	Training Accuracy=83.0%
# iter 100:	 Loss=0.41,	Training Accuracy=85.0%
# iter 200:	 Loss=0.43,	Training Accuracy=82.0%
# iter 300:	 Loss=0.40,	Training Accuracy=82.0%
# iter 400:	 Loss=0.38,	Training Accuracy=84.0%
# iter 500:	 Loss=0.31,	Training Accuracy=85.0%
# iter 600:	 Loss=0.35,	Training Accuracy=86.0%
# ---------------------------------------------------------
# Epoch: 3, validation loss: 0.41, validation accuracy: 85.0%
# ---------------------------------------------------------
# Training epoch: 4
# iter   0:	 Loss=0.20,	Training Accuracy=93.0%
# lr is changed 0.001
# lr is changed 0.0001
# lr is changed 1e-05
# iter 100:	 Loss=0.26,	Training Accuracy=88.0%
# iter 200:	 Loss=0.22,	Training Accuracy=91.0%
# iter 300:	 Loss=0.27,	Training Accuracy=91.0%
# iter 400:	 Loss=0.29,	Training Accuracy=87.0%
# iter 500:	 Loss=0.25,	Training Accuracy=91.0%
# iter 600:	 Loss=0.25,	Training Accuracy=90.0%
# ---------------------------------------------------------
# Epoch: 4, validation loss: 0.35, validation accuracy: 88.1%
# ---------------------------------------------------------
# Training epoch: 5
# iter   0:	 Loss=0.20,	Training Accuracy=94.0%
# iter 100:	 Loss=0.22,	Training Accuracy=90.0%
# iter 200:	 Loss=0.24,	Training Accuracy=91.0%
# iter 300:	 Loss=0.20,	Training Accuracy=94.0%
# iter 400:	 Loss=0.29,	Training Accuracy=88.0%
# iter 500:	 Loss=0.28,	Training Accuracy=90.0%
# iter 600:	 Loss=0.20,	Training Accuracy=93.0%
# ---------------------------------------------------------
# Epoch: 5, validation loss: 0.36, validation accuracy: 87.8%
# ---------------------------------------------------------
# Training epoch: 6
# iter   0:	 Loss=0.15,	Training Accuracy=95.0%
# lr is changed 1.0000000000000002e-06
# lr is changed 1.0000000000000002e-07
# iter 100:	 Loss=0.22,	Training Accuracy=89.0%
# iter 200:	 Loss=0.27,	Training Accuracy=90.0%
# iter 300:	 Loss=0.18,	Training Accuracy=91.0%
# iter 400:	 Loss=0.22,	Training Accuracy=91.0%
# iter 500:	 Loss=0.20,	Training Accuracy=93.0%
# iter 600:	 Loss=0.18,	Training Accuracy=95.0%
# ---------------------------------------------------------
# Epoch: 6, validation loss: 0.35, validation accuracy: 87.9%
# ---------------------------------------------------------
# model saved in ./saved_variable
# Training epoch: 7
# iter   0:	 Loss=0.16,	Training Accuracy=93.0%
# iter 100:	 Loss=0.21,	Training Accuracy=91.0%
# iter 200:	 Loss=0.17,	Training Accuracy=95.0%
# iter 300:	 Loss=0.19,	Training Accuracy=93.0%
# iter 400:	 Loss=0.24,	Training Accuracy=90.0%
# iter 500:	 Loss=0.29,	Training Accuracy=89.0%
# iter 600:	 Loss=0.16,	Training Accuracy=97.0%
# ---------------------------------------------------------
# Epoch: 7, validation loss: 0.35, validation accuracy: 88.4%
# ---------------------------------------------------------
# model saved in ./saved_variable
# Training epoch: 8
# iter   0:	 Loss=0.13,	Training Accuracy=96.0%
# lr is changed 1.0000000000000004e-08
# iter 100:	 Loss=0.21,	Training Accuracy=92.0%
# iter 200:	 Loss=0.31,	Training Accuracy=91.0%
# iter 300:	 Loss=0.20,	Training Accuracy=93.0%
# iter 400:	 Loss=0.21,	Training Accuracy=91.0%
# iter 500:	 Loss=0.22,	Training Accuracy=94.0%
# iter 600:	 Loss=0.11,	Training Accuracy=98.0%
# lr is changed 1.0000000000000005e-09
# ---------------------------------------------------------
# Epoch: 8, validation loss: 0.37, validation accuracy: 88.0%
# ---------------------------------------------------------
# Training epoch: 9
# iter   0:	 Loss=0.12,	Training Accuracy=94.0%
# iter 100:	 Loss=0.15,	Training Accuracy=95.0%
# iter 200:	 Loss=0.16,	Training Accuracy=95.0%
# iter 300:	 Loss=0.16,	Training Accuracy=95.0%
# iter 400:	 Loss=0.17,	Training Accuracy=95.0%
# iter 500:	 Loss=0.23,	Training Accuracy=92.0%
# iter 600:	 Loss=0.13,	Training Accuracy=97.0%
# ---------------------------------------------------------
# Epoch: 9, validation loss: 0.39, validation accuracy: 89.1%
# ---------------------------------------------------------
# model saved in ./saved_variable
# Training epoch: 10
# iter   0:	 Loss=0.10,	Training Accuracy=94.0%
# lr is changed 1.0000000000000006e-10
# iter 100:	 Loss=0.23,	Training Accuracy=92.0%
# iter 200:	 Loss=0.19,	Training Accuracy=92.0%
# iter 300:	 Loss=0.18,	Training Accuracy=94.0%
# iter 400:	 Loss=0.19,	Training Accuracy=93.0%
# iter 500:	 Loss=0.22,	Training Accuracy=90.0%
# iter 600:	 Loss=0.11,	Training Accuracy=98.0%
# ---------------------------------------------------------
# Epoch: 10, validation loss: 0.38, validation accuracy: 87.9%
# ---------------------------------------------------------
# Training epoch: 11
# iter   0:	 Loss=0.11,	Training Accuracy=97.0%
# iter 100:	 Loss=0.18,	Training Accuracy=95.0%
# iter 200:	 Loss=0.18,	Training Accuracy=94.0%
# iter 300:	 Loss=0.20,	Training Accuracy=93.0%
# iter 400:	 Loss=0.18,	Training Accuracy=92.0%
# iter 500:	 Loss=0.22,	Training Accuracy=92.0%
# iter 600:	 Loss=0.12,	Training Accuracy=97.0%
# ---------------------------------------------------------
# Epoch: 11, validation loss: 0.38, validation accuracy: 88.5%
# ---------------------------------------------------------
# Training epoch: 12
# iter   0:	 Loss=0.11,	Training Accuracy=95.0%
# iter 100:	 Loss=0.17,	Training Accuracy=95.0%
# iter 200:	 Loss=0.18,	Training Accuracy=96.0%
# iter 300:	 Loss=0.18,	Training Accuracy=95.0%
# iter 400:	 Loss=0.20,	Training Accuracy=95.0%
# iter 500:	 Loss=0.25,	Training Accuracy=93.0%
# iter 600:	 Loss=0.07,	Training Accuracy=100.0%
# lr is changed 1.0000000000000006e-11
# lr is changed 1.0000000000000006e-12
# ---------------------------------------------------------
# Epoch: 12, validation loss: 0.45, validation accuracy: 89.4%
# ---------------------------------------------------------
# model saved in ./saved_variable
# Training epoch: 13
# iter   0:	 Loss=0.10,	Training Accuracy=95.0%
# iter 100:	 Loss=0.10,	Training Accuracy=97.0%
# iter 200:	 Loss=0.23,	Training Accuracy=91.0%
# iter 300:	 Loss=0.14,	Training Accuracy=94.0%
# iter 400:	 Loss=0.17,	Training Accuracy=94.0%
# iter 500:	 Loss=0.24,	Training Accuracy=91.0%
# iter 600:	 Loss=0.14,	Training Accuracy=98.0%
# ---------------------------------------------------------
# Epoch: 13, validation loss: 0.47, validation accuracy: 88.0%
# ---------------------------------------------------------
# Training epoch: 14
# iter   0:	 Loss=0.10,	Training Accuracy=97.0%
# iter 100:	 Loss=0.14,	Training Accuracy=94.0%
# iter 200:	 Loss=0.18,	Training Accuracy=94.0%
# iter 300:	 Loss=0.17,	Training Accuracy=94.0%
# iter 400:	 Loss=0.16,	Training Accuracy=94.0%
# iter 500:	 Loss=0.22,	Training Accuracy=93.0%
# iter 600:	 Loss=0.14,	Training Accuracy=95.0%
# ---------------------------------------------------------
# Epoch: 14, validation loss: 0.46, validation accuracy: 87.6%
# ---------------------------------------------------------
# Training epoch: 15
# iter   0:	 Loss=0.14,	Training Accuracy=94.0%
# iter 100:	 Loss=0.13,	Training Accuracy=96.0%
# iter 200:	 Loss=0.19,	Training Accuracy=90.0%
# iter 300:	 Loss=0.16,	Training Accuracy=95.0%
# iter 400:	 Loss=0.20,	Training Accuracy=93.0%
# iter 500:	 Loss=0.16,	Training Accuracy=95.0%
# iter 600:	 Loss=0.10,	Training Accuracy=96.0%
# ---------------------------------------------------------
# Epoch: 15, validation loss: 0.57, validation accuracy: 88.3%
# ---------------------------------------------------------
# Training epoch: 16
# iter   0:	 Loss=0.05,	Training Accuracy=99.0%
# lr is changed 1.0000000000000007e-13
# iter 100:	 Loss=0.14,	Training Accuracy=95.0%
# iter 200:	 Loss=0.17,	Training Accuracy=93.0%
# iter 300:	 Loss=0.13,	Training Accuracy=94.0%
# iter 400:	 Loss=0.17,	Training Accuracy=95.0%
# iter 500:	 Loss=0.20,	Training Accuracy=94.0%
# iter 600:	 Loss=0.13,	Training Accuracy=95.0%
# ---------------------------------------------------------
# Epoch: 16, validation loss: 0.60, validation accuracy: 88.1%
# ---------------------------------------------------------
# Training epoch: 17
# iter   0:	 Loss=0.12,	Training Accuracy=95.0%
# iter 100:	 Loss=0.08,	Training Accuracy=96.0%
# iter 200:	 Loss=0.14,	Training Accuracy=95.0%
# iter 300:	 Loss=0.13,	Training Accuracy=95.0%
# iter 400:	 Loss=0.18,	Training Accuracy=96.0%
# iter 500:	 Loss=0.21,	Training Accuracy=93.0%
# iter 600:	 Loss=0.13,	Training Accuracy=95.0%
# ---------------------------------------------------------
# Epoch: 17, validation loss: 0.56, validation accuracy: 88.2%
# ---------------------------------------------------------
# Training epoch: 18
# iter   0:	 Loss=0.12,	Training Accuracy=97.0%
# iter 100:	 Loss=0.11,	Training Accuracy=96.0%
# iter 200:	 Loss=0.26,	Training Accuracy=92.0%
# iter 300:	 Loss=0.22,	Training Accuracy=94.0%
# iter 400:	 Loss=0.14,	Training Accuracy=95.0%
# iter 500:	 Loss=0.13,	Training Accuracy=95.0%
# iter 600:	 Loss=0.13,	Training Accuracy=96.0%
# ---------------------------------------------------------
# Epoch: 18, validation loss: 0.55, validation accuracy: 88.0%
# ---------------------------------------------------------
# Early stopping

# %%
# Test the network when training is done
x_test, y_test = xtest,ytest
feed_dict_test = {x: x_test, y: y_test}
loss_test, acc_test = sess.run([loss, accuracy], feed_dict=feed_dict_test)
print('---------------------------------------------------------')
print("Test loss: {0:.2f}, test accuracy: {1:.01%}".format(loss_test, acc_test))
print('---------------------------------------------------------')
# Out:
# ---------------------------------------------------------
# Test loss: 0.58, test accuracy: 89.1%
# ---------------------------------------------------------

# %%
tf.reset_default_graph()
imported_graph = tf.train.import_meta_graph('saved_variable.meta')
with tf.Session() as sess:
    imported_graph.restore(sess, './saved_variable')
     
    # print the loaded variable
    # Test the network when training is done
    x_test, y_test = xtest,ytest
    print(x_test.shape, y_test.shape)
    feed_dict_test = {'Input/X:0': x_test, 'Input/Y:0': y_test}
    loss_test, acc_test = sess.run(['Train/Loss/loss:0', 'Train/Accuracy/accuracy:0'], feed_dict=feed_dict_test)
    print('---------------------------------------------------------')
    print("Test loss: {0:.2f}, test accuracy: {1:.01%}".format(loss_test, acc_test))
    print('---------------------------------------------------------')

# %% [raw]
# batch size =100 , drpout true, 3x3, no max pooling at layer 1, learning rate =0.001
# INFO:tensorflow:Restoring parameters from ./saved_variable
# (10000, 28, 28, 1) (10000, 10)
# ---------------------------------------------------------
# Test loss: 0.27, test accuracy: 90.5%
# ---------------------------------------------------------

# %% [raw]
# batch size =100 , drpout true, 3x3, no max pooling at layer 1
# INFO:tensorflow:Restoring parameters from ./saved_variable
# (10000, 28, 28, 1) (10000, 10)
# ---------------------------------------------------------
# Test loss: 0.31, test accuracy: 90.5%
# ---------------------------------------------------------

# %% [raw]
# batch size =64 , drpout true, 3x3, no max pooling at layer 1
#
# (10000, 28, 28, 1) (10000, 10)
# ---------------------------------------------------------
# Test loss: 0.34, test accuracy: 90.0%
# ---------------------------------------------------------

# %% [raw]
# batch size =64 , drpout true, 3x3, max pooling at layer 1
#
# INFO:tensorflow:Restoring parameters from ./saved_variable
# (10000, 28, 28, 1) (10000, 10)
# ---------------------------------------------------------
# Test loss: 0.45, test accuracy: 86.8%
# ---------------------------------------------------------

# %% [raw]
# extra pooling at start and filter 3 and 256 bqtch size
# (10000, 28, 28, 1) (10000, 10)
# ---------------------------------------------------------
# Test loss: 0.34, test accuracy: 87.6%
# ---------------------------------------------------------

# %% [raw]
# filter size 3
#
# INFO:tensorflow:Restoring parameters from ./saved_variable
# (10000, 28, 28, 1) (10000, 10)
# ---------------------------------------------------------
# Test loss: 0.32, test accuracy: 89.6%
# ---------------------------------------------------------

# %% [raw]
# INFO:tensorflow:Restoring parameters from ./saved_variable
# (10000, 28, 28, 1) (10000, 10)
# ---------------------------------------------------------
# Test loss: 0.34, test accuracy: 90.6%
# ---------------------------------------------------------
# dropout in conv layer 1

# %% [raw]
# with out dropout in conv layer 1
#
# INFO:tensorflow:Restoring parameters from ./saved_variable
# (10000, 28, 28, 1) (10000, 10)
# ---------------------------------------------------------
# Test loss: 0.44, test accuracy: 89.0%
# ---------------------------------------------------------

# %%
# for i in  tf.get_default_graph().get_operations():
#     print(i.name,i.values())
